# %%
from __future__ import absolute_import, division, print_function

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys

sys.path.append("../gym-sepsis/")
import gym_sepsis
from gym_sepsis.envs.sepsis_env import SepsisEnv

# %%
data = np.load("../processed_data.npz")
df = pd.read_csv("/Users/amir/Downloads/test_state_action_reward_df.csv")

# %%
sepsis_env = SepsisEnv()

# %%
x = data['x_test']
y = data['y_test']

# %%
columns = ['ALBUMIN', 'ANION GAP', 'BANDS', 'BICARBONATE',
       'BILIRUBIN', 'BUN', 'CHLORIDE', 'CREATININE', 'DiasBP', 'Glucose',
       'GLUCOSE', 'HeartRate', 'HEMATOCRIT', 'HEMOGLOBIN', 'INR', 'LACTATE',
       'MeanBP', 'PaCO2', 'PLATELET', 'POTASSIUM', 'PT', 'PTT', 'RespRate',
       'SODIUM', 'SpO2', 'SysBP', 'TempC', 'WBC', 'age', 'is_male',
       'race_white', 'race_black', 'race_hispanic', 'race_other', 'height',
       'weight', 'vent', 'sofa', 'lods', 'sirs', 'qsofa', 'qsofa_sysbp_score',
       'qsofa_gcs_score', 'qsofa_resprate_score', 'elixhauser_hospital',
       'blood_culture_positive', 'action', 'state_idx']

# %%
df.iloc[6:23]
# Out:
#     subject_id  hadm_id  icustay_id   interval_start_time  \
# 6          145   198161      226841  2144-03-29T19:00:00Z
# 7          145   198161      226841  2144-03-29T23:00:00Z
# 8          145   198161      226841  2144-03-30T03:00:00Z
# 9          145   198161      226841  2144-03-30T07:00:00Z
# 10         145   198161      226841  2144-03-30T11:00:00Z
# 11         145   198161      226841  2144-03-30T15:00:00Z
# 12         145   198161      226841  2144-03-30T19:00:00Z
# 13         145   198161      226841  2144-03-30T23:00:00Z
# 14         145   198161      226841  2144-03-31T03:00:00Z
# 15         145   198161      226841  2144-03-31T07:00:00Z
# 16         145   198161      226841  2144-03-31T11:00:00Z
# 17         145   198161      226841  2144-03-31T15:00:00Z
# 18         145   198161      226841  2144-03-31T19:00:00Z
# 19         145   198161      226841  2144-03-31T23:00:00Z
# 20         145   198161      226841  2144-04-01T03:00:00Z
# 21         145   198161      226841  2144-04-01T07:00:00Z
# 22         145   198161      226841  2144-04-01T11:00:00Z
#
#        interval_end_time   ALBUMIN  ANION GAP     BANDS  BICARBONATE  \
# 6   2144-03-29T23:00:00Z -0.058925   0.023291 -0.297663    -0.600421
# 7   2144-03-30T03:00:00Z  0.083825  -0.721072 -0.297663    -0.386614
# 8   2144-03-30T07:00:00Z  0.083825  -0.721072 -0.297663    -0.386614
# 9   2144-03-30T11:00:00Z  0.083825  -0.721072 -0.297663    -0.386614
# 10  2144-03-30T15:00:00Z  0.083825  -0.721072 -0.297663    -0.386614
# 11  2144-03-30T19:00:00Z  0.083825  -0.721072 -0.297663    -1.669454
# 12  2144-03-30T23:00:00Z  0.083825  -0.472951 -0.297663    -1.669454
# 13  2144-03-31T03:00:00Z  0.083825  -0.472951 -0.297663    -1.669454
# 14  2144-03-31T07:00:00Z  0.083825  -0.969193 -0.297663    -1.028034
# 15  2144-03-31T11:00:00Z  0.083825  -0.969193 -0.297663    -1.028034
# 16  2144-03-31T15:00:00Z  0.083825  -0.969193 -0.297663    -1.028034
# 17  2144-03-31T19:00:00Z  0.083825  -0.969193 -0.297663    -1.028034
# 18  2144-03-31T23:00:00Z  0.083825  -0.969193 -0.297663    -1.028034
# 19  2144-04-01T03:00:00Z  0.083825  -0.969193 -0.297663    -1.028034
# 20  2144-04-01T07:00:00Z  0.083825  -0.969193 -0.297663    -1.241840
# 21  2144-04-01T11:00:00Z  0.083825  -0.969193 -0.297663    -1.241840
# 22  2144-04-01T15:00:00Z  0.083825  -0.969193 -0.297663    -1.241840
#
#     BILIRUBIN  ...  qsofa_sysbp_score  qsofa_gcs_score  qsofa_resprate_score  \
# 6   -0.293952  ...           0.540022         1.727312              0.390655
# 7   -0.248334  ...           0.540022         1.727312              0.390655
# 8   -0.248334  ...           0.540022         1.727312              0.390655
# 9   -0.248334  ...           0.540022         1.727312              0.390655
# 10  -0.248334  ...           0.540022         1.727312              0.390655
# 11  -0.248334  ...           0.540022         1.727312              0.390655
# 12  -0.248334  ...           0.540022         1.727312              0.390655
# 13  -0.248334  ...           0.540022         1.727312              0.390655
# 14  -0.248334  ...           0.540022         1.727312              0.390655
# 15  -0.248334  ...           0.540022         1.727312              0.390655
# 16  -0.248334  ...           0.540022         1.727312              0.390655
# 17  -0.248334  ...           0.540022         1.727312              0.390655
# 18  -0.248334  ...           0.540022         1.727312              0.390655
# 19  -0.248334  ...           0.540022         1.727312              0.390655
# 20  -0.248334  ...           0.540022         1.727312              0.390655
# 21  -0.248334  ...           0.540022         1.727312              0.390655
# 22  -0.248334  ...           0.540022         1.727312              0.390655
#
#     elixhauser_hospital  blood_culture_positive  discrete_action  \
# 6              1.465021               -0.684186               20
# 7              1.465021               -0.684186               15
# 8              1.465021               -0.684186               15
# 9              1.465021               -0.684186               10
# 10             1.465021               -0.684186                0
# 11             1.465021               -0.684186                0
# 12             1.465021               -0.684186               10
# 13             1.465021               -0.684186               20
# 14             1.465021               -0.684186               15
# 15             1.465021               -0.684186               20
# 16             1.465021               -0.684186               15
# 17             1.465021               -0.684186               15
# 18             1.465021               -0.684186               15
# 19             1.465021               -0.684186               15
# 20             1.465021               -0.684186               15
# 21             1.465021               -0.684186               15
# 22             1.465021               -0.684186               15
#
#     hospital_expire_flag  reward  row_id  row_id_next
# 6                      0       0     6.0          7.0
# 7                      0       0     7.0          8.0
# 8                      0       0     8.0          9.0
# 9                      0       0     9.0         10.0
# 10                     0       0    10.0         11.0
# 11                     0       0    11.0         12.0
# 12                     0       0    12.0         13.0
# 13                     0       0    13.0         14.0
# 14                     0       0    14.0         15.0
# 15                     0       0    15.0         16.0
# 16                     0       0    16.0         17.0
# 17                     0       0    17.0         18.0
# 18                     0       0    18.0         19.0
# 19                     0       0    19.0         20.0
# 20                     0       0    20.0         21.0
# 21                     0       0    21.0         22.0
# 22                     0       0    22.0         23.0
#
# [17 rows x 56 columns]

# %%
# sns.set(style="white")
from matplotlib.pyplot import figure
    

def plot(column, start, end, sepsis_env):
    simulated_states = np.zeros(shape=(end - start, x[start].shape[0] - 1))
    simulated_states[0] = np.squeeze(sepsis_env.reset(starting_state=x[start][:-1]))
    doctor_actions = x[start:end][:,46]
    for i in range(1, end - start):
        simulated_states[i, :] = np.squeeze(sepsis_env.step(doctor_actions[i])[0])
        
    plt.plot(np.array(x[start:end, columns.index(column)]), label="truth", scaley=False)
    plt.plot(np.array(simulated_states[:,columns.index(column)]), label="predicted", scaley=False)
    plt.ylim(-2, 2)
    plt.legend(["truth", "predicted"])
    plt.title(column)

# %%
columns.index("age")
# Out:
# 28

# %%
plot("age" ,6, 23, sepsis_env)

# %%
plot("SpO2" ,6, 23, sepsis_env)

# %%
plot("sofa" ,6, 23, sepsis_env)

# %%
plot("WBC" ,6, 23, sepsis_env)

# %%
plot("HeartRate" ,6, 24, sepsis_env)
